# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Plot the distribution curve for the 'ConvertedComp' column
plt.figure(figsize=(10, 6))
sns.histplot(df['ConvertedComp'].dropna(), kde=True)
plt.title('Distribution of Annual USD Salaries (ConvertedComp)')
plt.xlabel('Annual Salary (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Plot the histogram for the 'ConvertedComp' column
plt.figure(figsize=(10, 6))
sns.histplot(df['ConvertedComp'].dropna(), kde=False)
plt.title('Histogram of Annual USD Salaries (ConvertedComp)')
plt.xlabel('Annual Salary (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate the median of the 'ConvertedComp' column
median_converted_comp = df['ConvertedComp'].median()

# Print the median
print(f"The median of the 'ConvertedComp' column is: {median_converted_comp}")
# Out:
# The median of the 'ConvertedComp' column is: 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Count the number of respondents who identified themselves only as a Man
num_respondents_man = df[df['Gender'] == 'Man']['Respondent'].nunique()

# Print the number of respondents who identified themselves only as a Man
print(f"The number of respondents who identified themselves only as a Man is: {num_respondents_man}")
# Out:
# The number of respondents who identified themselves only as a Man is: 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Filter the DataFrame to include only respondents who identified themselves as a Woman
df_women = df[df['Gender'] == 'Woman']

# Calculate the median of the 'ConvertedComp' for these respondents
median_converted_comp_women = df_women['ConvertedComp'].median()

# Print the median
print(f"The median ConvertedComp of respondents who identified themselves only as a Woman is: {median_converted_comp_women}")
# Out:
# The median ConvertedComp of respondents who identified themselves only as a Woman is: 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Get the five-number summary for the 'Age' column
age_summary = df['Age'].describe()

# Extracting the five-number summary from the describe() output
min_age = age_summary['min']
q1_age = df['Age'].quantile(0.25)
median_age = age_summary['50%']
q3_age = df['Age'].quantile(0.75)
max_age = age_summary['max']

# Print the five-number summary
print(f"Minimum age: {min_age}")
print(f"First quartile (Q1) age: {q1_age}")
print(f"Median age: {median_age}")
print(f"Third quartile (Q3) age: {q3_age}")
print(f"Maximum age: {max_age}")
# Out:
# Minimum age: 16.0
# First quartile (Q1) age: 25.0
# Median age: 29.0
# Third quartile (Q3) age: 35.0
# Maximum age: 99.0

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Plot the histogram for the 'Age' column
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'].dropna(), kde=False, bins=30)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# What age group has the highest number of survey respondents based on the histogram.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Define age bins
bins = [0, 18, 25, 35, 45, 55, 65, 100]
labels = ['0-18', '19-25', '26-35', '36-45', '46-55', '56-65', '66+']

# Create a new column for age groups
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Count the number of respondents in each age group
age_group_counts = df['AgeGroup'].value_counts()

# Find the age group with the highest number of respondents
most_common_age_group = age_group_counts.idxmax()
most_common_age_group_count = age_group_counts.max()

# Print the most common age group and the count
print(f"The age group with the highest number of survey respondents is: {most_common_age_group} with {most_common_age_group_count} respondents")
# Out:
# The age group with the highest number of survey respondents is: 26-35 with 6213 respondents

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Plot the box plot for the 'ConvertedComp' column
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['ConvertedComp'].dropna())
plt.title('Box Plot of ConvertedComp')
plt.xlabel('Annual Salary (USD)')
plt.show()

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# Print the IQR
print(f"The Interquartile Range (IQR) for the 'ConvertedComp' column is: {iqr}")
# Out:
# The Interquartile Range (IQR) for the 'ConvertedComp' column is: 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# Calculate the lower bound
lower_bound = q1 - 1.5 * iqr

# Calculate the upper bound
upper_bound = q3 + 1.5 * iqr

# Print the bounds
print(f"The lower bound for the 'ConvertedComp' column is: {lower_bound}")
print(f"The upper bound for the 'ConvertedComp' column is: {upper_bound}")
# Out:
# The lower bound for the 'ConvertedComp' column is: -82830.0
# The upper bound for the 'ConvertedComp' column is: 209698.0

# %%
# Based on the boxplot of ‘Age’ how many outliers do you see below Q1?

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate Q1 (25th percentile), Q3 (75th percentile), and IQR
q1 = df['Age'].quantile(0.25)
q3 = df['Age'].quantile(0.75)
iqr = q3 - q1

# Calculate the lower bound
lower_bound = q1 - 1.5 * iqr

# Identify outliers below Q1
outliers_below_q1 = df[df['Age'] < lower_bound]

# Count the number of outliers below Q1
num_outliers_below_q1 = outliers_below_q1.shape[0]

# Print the number of outliers below Q1
print(f"The number of outliers below Q1 in the 'Age' column is: {num_outliers_below_q1}")
# Out:
# The number of outliers below Q1 in the 'Age' column is: 0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# Calculate the lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Identify outliers
outliers = df[(df['ConvertedComp'] < lower_bound) | (df['ConvertedComp'] > upper_bound)]

# Count the number of outliers
num_outliers = outliers.shape[0]

# Print the number of outliers
print(f"The number of outliers in the 'ConvertedComp' column is: {num_outliers}")
# Out:
# The number of outliers in the 'ConvertedComp' column is: 879

# %%
# What is the median ConvertedComp before removing outliers?

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate the median of the 'ConvertedComp' column before removing outliers
median_converted_comp_before_outliers = df['ConvertedComp'].median()

# Print the median
print(f"The median ConvertedComp before removing outliers is: {median_converted_comp_before_outliers}")
# Out:
# The median ConvertedComp before removing outliers is: 57745.0

# %%
# What is the mean ConvertedComp after removing outliers?

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# Calculate the lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Create a new DataFrame by removing the outliers
df_no_outliers = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]

# Calculate the mean of the 'ConvertedComp' column after removing outliers
mean_converted_comp_after_outliers = df_no_outliers['ConvertedComp'].mean()

# Print the mean
print(f"The mean ConvertedComp after removing outliers is: {mean_converted_comp_after_outliers}")
# Out:
# The mean ConvertedComp after removing outliers is: 59883.20838915799

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# Calculate the lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Create a new DataFrame by removing the outliers
df_no_outliers = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]

# Print the shape of the new DataFrame to verify the number of rows remaining
print(f"The shape of the new DataFrame after removing outliers is: {df_no_outliers.shape}")
# Out:
# The shape of the new DataFrame after removing outliers is: (9703, 85)

# %%
# What is the median ConvertedComp after removing outliers?

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# Calculate the lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Create a new DataFrame by removing the outliers
df_no_outliers = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]

# Calculate the median of the 'ConvertedComp' column after removing outliers
median_converted_comp_after_outliers = df_no_outliers['ConvertedComp'].median()

# Print the median
print(f"The median ConvertedComp after removing outliers is: {median_converted_comp_after_outliers}")
# Out:
# The median ConvertedComp after removing outliers is: 52704.0

# %%
# Median ConvertedComp of respondents identified as ‘Woman’

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Filter the DataFrame to include only respondents who identified themselves as 'Woman'
df_women = df[df['Gender'] == 'Woman']

# Calculate the median of the 'ConvertedComp' for these respondents
median_converted_comp_women = df_women['ConvertedComp'].median()

# Print the median
print(f"The median ConvertedComp of respondents who identified themselves as 'Woman' is: {median_converted_comp_women}")
# Out:
# The median ConvertedComp of respondents who identified themselves as 'Woman' is: 57708.0

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here

import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# Select only numerical columns
numerical_columns = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_columns.corr()

# Extract the correlation of 'Age' with other numerical columns
age_correlation = correlation_matrix['Age']

# Print the correlation of 'Age' with other numerical columns
print("Correlation between Age and other numerical columns:")
print(age_correlation)
# Out:
# Correlation between Age and other numerical columns:
# Respondent       0.004041
# CompTotal        0.006970
# ConvertedComp    0.105386
# WorkWeekHrs      0.036518
# CodeRevHrs      -0.020469
# Age              1.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
